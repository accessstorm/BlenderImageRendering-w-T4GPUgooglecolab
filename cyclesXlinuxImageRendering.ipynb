# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/drive/')

# %% [markdown]
# Downlaod Blender

# %%
#!wget -c https://cdn.builder.blender.org/download/daily/blender-4.2.6-candidate+v42.f13c01f4e283-linux.x86_64-release.tar.xz

# %%
#!ls

# %% [markdown]
# Unzip the file

# %%
#!tar xf blender-4.2.6-candidate+v42.f13c01f4e283-linux.x86_64-release.tar.xz

# %% [markdown]
# Set variable

# %%
filename = '/drive/MyDrive/Blender/fordmustang/Sketchfab_2023_03_29_22_02_26.blend'

# %% [markdown]
# Error fix while running blender

# %%
# !chmod +x /drive/MyDrive/Blender4-2/blender

# %% [markdown]
# Running blender

# %%
# !/drive/MyDrive/Blender4-2/blender -b $filename -noaudio -E 'CYCLES' -o '/drive/MyDrive/Blender/fordmustang' -f 1 -F 'PNG' -- --cycles-device OPTIX
